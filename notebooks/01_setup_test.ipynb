# %% [markdown]
# <a href="https://colab.research.google.com/github/DhikshaSubash/market-sentiment-analysis/blob/main/notebooks/01_setup_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark -q

from pyspark.sql import SparkSession

spark = SparkSession.builder \
    .appName("MarketSentimentAnalysis") \
    .getOrCreate()

print("✅ Spark is working!")
print(f"Spark version: {spark.version}")
# Out:
# ✅ Spark is working!
# Spark version: 4.0.2
